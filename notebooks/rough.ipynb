# %%
import numpy as np
import wandb

wandb_run = wandb.init(
        entity="DA6401_assignment01",
        project="assignment_01",
        id = "Q2.1"
    )

def log_sample_images(x, y, dataset_name):

    class_names = {
        "mnist": [str(i) for i in range(10)],
        "fashion_mnist": [
            "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
            "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
        ]
    }

    table = wandb.Table(columns=["class", "image"])

    for cls in range(10):

        indices = np.where(y == cls)[0][:5]

        for idx in indices:
            img = x[idx]
            table.add_data(class_names[dataset_name][cls],
                           wandb.Image(img))

    wandb.log({"sample_images": table})
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/mk009/.netrc.
# wandb: Currently logged in as: ae21b036 (DA6401_assignment01) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/home/mk009/DA6401/ae21b036_da6401_assignment-01/notebooks/wandb/run-20260226_220536-Q2.1</code>
# Syncing run <strong><a href='https://wandb.ai/DA6401_assignment01/assignment_01/runs/Q2.1' target="_blank">Q2.1</a></strong> to <a href='https://wandb.ai/DA6401_assignment01/assignment_01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/DA6401_assignment01/assignment_01' target="_blank">https://wandb.ai/DA6401_assignment01/assignment_01</a>
# ...

# %%
from tensorflow.keras import datasets

_,(x,y) = datasets.mnist.load_data()

log_sample_images(x,y,'mnist')
# Out:
# 2026-02-26 22:05:41.416495: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-26 22:05:41.479593: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-26 22:05:43.127772: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
wandb.finish()
# Out:
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
#  View run <strong style="color:#cdcd00">Q2.1</strong> at: <a href='https://wandb.ai/DA6401_assignment01/assignment_01/runs/Q2.1' target="_blank">https://wandb.ai/DA6401_assignment01/assignment_01/runs/Q2.1</a><br> View project at: <a href='https://wandb.ai/DA6401_assignment01/assignment_01' target="_blank">https://wandb.ai/DA6401_assignment01/assignment_01</a><br>Synced 4 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260226_220536-Q2.1/logs</code>
